# %%
# Import dependencies
import pandas as pd
from datetime import date

# %%
# File to load
walmart_data = pd.read_csv('Walmart.csv')

# %%
# Display data table for preview
walmart_data.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
# View the datatypes
walmart_data.dtypes
# Out:
# Store             int64
# Date             object
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %%
# Change Date datatype from object to date
walmart_data['Date'] = pd.to_datetime(walmart_data['Date'], infer_datetime_format=True, dayfirst=True)

# %%
# View the datatypes
walmart_data.dtypes
# Out:
# Store                    int64
# Date            datetime64[ns]
# Weekly_Sales           float64
# Holiday_Flag             int64
# Temperature            float64
# Fuel_Price             float64
# CPI                    float64
# Unemployment           float64
# dtype: object

# %%
# Display data table for preview
walmart_data.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
# Check for missing values
for col in walmart_data.columns.tolist():
  print('{} column missing values: {}'.format(col, walmart_data[col].isnull().sum()))
# Out:
# Store column missing values: 0
# Date column missing values: 0
# Weekly_Sales column missing values: 0
# Holiday_Flag column missing values: 0
# Temperature column missing values: 0
# Fuel_Price column missing values: 0
# CPI column missing values: 0
# Unemployment column missing values: 0

# %%
# Check Holiday_Flag unique values
walmart_data['Holiday_Flag'].unique()
# Out:
# array([0, 1])

# %%
# Create new column Holiday_Week to convert Holiday_Flag variable from integer to object, then drop Holiday_Flag
walmart_data['Holiday_Week'] = ''

def applyHoliday(h):
  if h == 1:
    return 'Holiday Week'
  else:
    return 'Not Holiday Week'

walmart_data['Holiday_Week'] = walmart_data['Holiday_Flag'].apply(applyHoliday)

walmart_data = walmart_data.drop('Holiday_Flag', axis=1)

# %%
# Display data table for preview
walmart_data.head()
# Out:
#    Store       Date  Weekly_Sales  Temperature  Fuel_Price         CPI  \
# 0      1 2010-02-05    1643690.90        42.31       2.572  211.096358
# 1      1 2010-02-12    1641957.44        38.51       2.548  211.242170
# 2      1 2010-02-19    1611968.17        39.93       2.514  211.289143
# 3      1 2010-02-26    1409727.59        46.63       2.561  211.319643
# 4      1 2010-03-05    1554806.68        46.50       2.625  211.350143
#
#    Unemployment      Holiday_Week
# 0         8.106  Not Holiday Week
# 1         8.106      Holiday Week
# 2         8.106  Not Holiday Week
# 3         8.106  Not Holiday Week
# 4         8.106  Not Holiday Week

# %%
# Check for duplicate rows
walmart_data[walmart_data.duplicated]
# Out:
# Empty DataFrame
# Columns: [Store, Date, Weekly_Sales, Temperature, Fuel_Price, CPI, Unemployment, Holiday_Week]
# Index: []

# %%
# Export cleaned data to CSV
walmart_data.to_csv('Walmart_Clean.csv', index=False)
